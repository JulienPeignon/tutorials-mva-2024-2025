# %% [markdown]
# **Machine Learning for Time Series (Master MVA)**
#
# - [Link to the class material.](http://www.laurentoudre.fr/ast.html)

# %% [markdown]
# # Introduction
#
# In this tutorial, we illustrate the following concepts:
#
# - feature extraction on time series
# - feature selection

# %% [markdown]
# ## Setup
#
# **Imports**

# %%
from itertools import tee

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from loadmydata.load_uea_ucr import load_uea_ucr_data
from numpy.fft import rfft, rfftfreq
from scipy.cluster import hierarchy
from scipy.signal import argrelmax, stft
from scipy.spatial.distance import pdist, squareform
from scipy.stats import f_oneway, spearmanr
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, make_scorer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_selection import SequentialFeatureSelector
from statsmodels.tsa.stattools import acf

# %% [markdown]
# **Utility functions**

# %%
def pairwise(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = tee(iterable)
    next(b, None)
    return zip(a, b)

# %%
def get_largest_local_max(signal1D: np.ndarray, order: int = 1):
    """Return the largest local max and the associated index in a tuple.

    This function uses `order` points on each side to use for the comparison.
    """
    all_local_max_indexes = argrelmax(signal1D, order=order)[0]
    all_local_max = np.take(signal1D, all_local_max_indexes)
    largest_local_max_index = all_local_max_indexes[all_local_max.argsort()[-1]]

    return signal1D[largest_local_max_index], largest_local_max_index

# %%
def fig_ax(figsize=(15, 5)):
    return plt.subplots(figsize=figsize)

# %% [markdown]
# ## Data

# %%
# fmt: off
X_train = np.loadtxt("BinaryHeartbeat.csv").reshape((204, 18530, 1))
y_train = np.array(['Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Abnormal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal'])
# fmt: on

# Sampling frequency
FREQUENCY = 2000  # Hz

# %% [markdown]
# Choose a signal from the data set.

# %%
ind = 3
signal = X_train[ind].flatten()
label = y_train[ind]
n_samples = signal.shape[0]
print(label)
# Out:
# Abnormal

# %%
fig, ax = fig_ax()
tt = np.arange(n_samples) / FREQUENCY
ax.plot(tt, signal)
_ = ax.set_xlim(0, n_samples / FREQUENCY)

# %% [markdown]
# Compute the spectrogram

# %%
f, t, Zxx = stft(signal, fs=FREQUENCY, nperseg=1000, noverlap=800)

# %%
fig, ax = fig_ax()
ax.pcolormesh(t, f, np.abs(Zxx), vmin=0, shading="gouraud")
ax.set_xlabel("Time (s)")
_ = ax.set_ylabel("Frequency (Hz)")

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>Replot the same spectrogram as above, but zoom on the interesting frequencies (set <tt>cut_off_freq</tt> in the following cell).</p>
#     <ul>
#         <li>What are the repeated patterns? What is the frequency of interest (approximately)?</li>
#         <li>What happens when you increase the number of samples per windows?</li>
#         <li>What happens when you increase the overlap between windows?</li>
#     </ul>
# </div>

# %%
# Cut-off frequency
cut_off_freq = 200  # Hz

# %%
fig, ax = fig_ax()

f, t, Zxx = stft(signal, fs=FREQUENCY, nperseg=1024, noverlap=512)

keep_mask = f < cut_off_freq

ax.pcolormesh(
    t, f[keep_mask], np.abs(Zxx[keep_mask]), vmin=0, shading="gouraud"
)
ax.set_xlabel("Time (s)")
_ = ax.set_ylabel("Frequency (Hz)")

# %% [markdown]
# # Feature extraction

# %% [markdown]
# ## Statistical features

# %% [markdown]
# ### Moments and percentiles

# %%
def get_distribution_features(signal: np.ndarray) -> dict:
    res_dict = dict()
    res_dict["mean"] = signal.mean()
    res_dict["std"] = signal.std()
    res_dict["min"] = signal.min()
    res_dict["max"] = signal.max()
    return res_dict

# %%
get_distribution_features(signal)
# Out:
# {'mean': np.float64(-2.6195999439287612e-05),
#  'std': np.float64(0.07553291087476237),
#  'min': np.float64(-0.4403687),
#  'max': np.float64(0.6446533)}

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> Rewrite in the following cell, the function <tt>get_distribution_features(signal)->dict</tt> so that is also computes the kurtosis, the skew (available in the <tt>scipy.stats</tt> module) and the 25%, 50% and 75% percentiles.</p>
# </div>

# %%
import scipy.stats as sts

def get_distribution_features(signal: np.ndarray) -> dict:
    res_dict = dict()
    res_dict["mean"] = signal.mean()
    res_dict["std"] = signal.std()
    res_dict["min"] = signal.min()
    res_dict["max"] = signal.max()
    res_dict["kurtosis"] = sts.kurtosis(signal)
    res_dict["skew"] = sts.skew(signal)
    res_dict["q0.25"], res_dict["q0.50"], res_dict["q0.75"] = sts.mstats.mquantiles(signal,[0.25,0.5,0.75])
    return res_dict

# %%
get_distribution_features(signal)
# Out:
# {'mean': np.float64(-2.6195999439287612e-05),
#  'std': np.float64(0.07553291087476237),
#  'min': np.float64(-0.4403687),
#  'max': np.float64(0.6446533),
#  'kurtosis': np.float64(15.069250155393355),
#  'skew': np.float64(1.424710311802977),
#  'q0.25': np.float64(-0.02001953),
#  'q0.50': np.float64(-0.0002746582),
#  'q0.75': np.float64(0.01864624)}

# %% [markdown]
# ### Autocorrelation

# %% [markdown]
# For a signal $x\in\mathbb{R}^N$ with $N$ samples, the autocorrelation with lag $m$ is defined as follows:
#
# $$
# \hat{\gamma}[m] := \frac{1}{N-|m|} \sum_{n=0}^{N -|m|-1} x[n]x[n+m].
# $$
#
# Note that if the signal $x$ is periodic, then the autocorrelation is also periodic with same period.

# %% [markdown]
# Let us plot the autocorrelation of a sound signal.

# %%
fig, ax = fig_ax()
ax.plot(acf(signal, nlags=200, fft=True), ".-")
ax.axhline(0, ls="--", color="k")
plt.show()

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>We would like to also compute the maximum autocorrelation value and the associated lag in Hz (a local maximum that is not 0). Explain how you can convert a lag expressed in number of samples to a lag expressed in Hz.</p>
# </div>

# %%
period = FREQUENCY / 70
print(period)
# Out:
# 28.571428571428573

# %% [markdown]
# Compute the autocorrelation features.

# %%
def get_autocorr_features(signal: np.ndarray, n_lags: int = 200) -> dict:
    auto_corr = acf(signal, nlags=n_lags, fft=True)
    res_dict = dict()
    for lag, auto_corr_value in enumerate(auto_corr):
        res_dict[f"autocorrelation_{lag}_lag"] = auto_corr_value
    local_max, local_argmax = auto_corr[:25].max(), auto_corr[25:].argmax() + 25
    res_dict["lag_max_autocorrelation_Hz"] = FREQUENCY / local_argmax
    res_dict["max_autocorrelation"] = local_max

    return res_dict

# %%
get_autocorr_features(signal, n_lags=100)
# Out:
# {'autocorrelation_0_lag': np.float64(1.0),
#  'autocorrelation_1_lag': np.float64(0.9850055864609748),
#  'autocorrelation_2_lag': np.float64(0.9418538165034437),
#  'autocorrelation_3_lag': np.float64(0.8735145181165255),
#  'autocorrelation_4_lag': np.float64(0.7843181525984161),
#  'autocorrelation_5_lag': np.float64(0.6794504024816174),
#  'autocorrelation_6_lag': np.float64(0.5641022384259385),
#  'autocorrelation_7_lag': np.float64(0.44344874752905994),
#  'autocorrelation_8_lag': np.float64(0.32208879174078264),
#  'autocorrelation_9_lag': np.float64(0.203993758755595),
#  'autocorrelation_10_lag': np.float64(0.09223255876203246),
#  'autocorrelation_11_lag': np.float64(-0.010920557907652518),
#  'autocorrelation_12_lag': np.float64(-0.10398259052847021),
#  'autocorrelation_13_lag': np.float64(-0.1860140045458254),
#  'autocorrelation_14_lag': np.float64(-0.2565175489605066),
#  'autocorrelation_15_lag': np.float64(-0.31536885315805047),
#  'autocorrelation_16_lag': np.float64(-0.3627484644649048),
#  'autocorrelation_17_lag': np.float64(-0.3991712693716528),
#  'autocorrelation_18_lag': np.float64(-0.4253873352745863),
#  'autocorrelation_19_lag': np.float64(-0.4423100286290333),
#  'autocorrelation_20_lag': np.float64(-0.4508615574945477),
#  'autocorrelation_21_lag': np.float64(-0.45194881342206517),
#  'autocorrelation_22_lag': np.float64(-0.44641062762441086),
#  'autocorrelation_23_lag': np.float64(-0.4350081031774435),
#  'autocorrelation_74_lag': np.float64(0.07228576428868559),
#  'autocorrelation_75_lag': np.float64(0.053845951050315435),
#  'autocorrelation_76_lag': np.float64(0.03418239318211477),
#  'autocorrelation_77_lag': np.float64(0.013479109062250702),
#  'autocorrelation_78_lag': np.float64(-0.008038487182986508),
#  'autocorrelation_79_lag': np.float64(-0.0300765650100232),
#  'autocorrelation_80_lag': np.float64(-0.05229122673759685),
#  'autocorrelation_81_lag': np.float64(-0.07425368428726083),
#  'autocorrelation_82_lag': np.float64(-0.09553326872460557),
#  'autocorrelation_83_lag': np.float64(-0.11564533605807643),
#  'autocorrelation_84_lag': np.float64(-0.13410532451802434),
#  'autocorrelation_85_lag': np.float64(-0.15041377722773905),
#  'autocorrelation_86_lag': np.float64(-0.16407766608135926),
#  'autocorrelation_87_lag': np.float64(-0.1746362010802762),
#  'autocorrelation_88_lag': np.float64(-0.18166266782707347),
#  'autocorrelation_89_lag': np.float64(-0.18482542091805076),
#  'autocorrelation_90_lag': np.float64(-0.18386832591762425),
#  'autocorrelation_91_lag': np.float64(-0.17869858040907408),
#  'autocorrelation_92_lag': np.float64(-0.16935341552622443),
#  'autocorrelation_93_lag': np.float64(-0.15603818834298086),
#  'autocorrelation_94_lag': np.float64(-0.13912316150718715),
#  'autocorrelation_95_lag': np.float64(-0.11910791389085279),
#  'autocorrelation_96_lag': np.float64(-0.0966182464342724),
#  'autocorrelation_97_lag': np.float64(-0.07235094417532614),
#  'autocorrelation_98_lag': np.float64(-0.04706207551936203),
#  'autocorrelation_99_lag': np.float64(-0.021513159849207535),
#  'autocorrelation_100_lag': np.float64(0.0035372436745553493),
#  'lag_max_autocorrelation_Hz': np.float64(30.76923076923077),
#  'max_autocorrelation': np.float64(1.0)}

# %% [markdown]
# ## Spectral features

# %% [markdown]
# Plot the Fourier coefficients of a signal (y=absolute value, x=frequency) using `rfft()` and `rfftfreq()`.

# %%
fourier = abs(rfft(signal)) ** 2
freqs = rfftfreq(n=n_samples, d=1.0 / FREQUENCY)

fig, ax = fig_ax()
ax.plot(freqs, fourier)
ax.set_xlabel("Frequency (Hz)")
_ = ax.set_ylabel("Fourier coefficient")

# %% [markdown]
# Compute the spectral features.

# %%
def get_fourier_features(signal: np.ndarray, n_bins: int = 100) -> dict:
    """The signal is assumed to be centered and scaled to unit variance."""
    n_samples = signal.shape[0]
    fourier = abs(rfft(signal))
    freqs = rfftfreq(n=n_samples, d=1.0 / FREQUENCY)
    res_dict = dict()

    freq_bins = np.linspace(0, FREQUENCY / 2, n_bins + 1)
    for f_min, f_max in pairwise(freq_bins):
        keep = (f_min <= freqs) & (freqs < f_max)
        res_dict[f"fourier_{f_min:.0f}-{f_max:.0f}_Hz"] = np.log(
            np.sum(fourier[keep] ** 2)
        )
    return res_dict

# %%
get_fourier_features(signal, n_bins=10)
# Out:
# {'fourier_0-100_Hz': np.float64(18.9183232970043),
#  'fourier_100-200_Hz': np.float64(15.763846447048538),
#  'fourier_200-300_Hz': np.float64(11.703739230823805),
#  'fourier_300-400_Hz': np.float64(10.314172071045125),
#  'fourier_400-500_Hz': np.float64(8.925445937663142),
#  'fourier_500-600_Hz': np.float64(8.513287464804487),
#  'fourier_600-700_Hz': np.float64(8.425193843189616),
#  'fourier_700-800_Hz': np.float64(8.462656599462498),
#  'fourier_800-900_Hz': np.float64(8.346392446653113),
#  'fourier_900-1000_Hz': np.float64(7.7626698220274495)}

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>The frequency features are not scaled. If the signal is normalized, do we need to?</p>
# </div>

# %% [markdown]
# Perceval

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> We have used regularly spaced frequency bins. What would be a better approach? </p>
#
# </div>

# %% [markdown]
# On préfère être plus précis au début de la série, qu'à la fin où il ne se passe rien

# %% [markdown]
# ## Concatenate all features

# %% [markdown]
# In the following cell, we write a function `get_features(signal: np.ndarray) -> dict` that computes all features from above.

# %%
def get_features(signal: np.ndarray) -> dict:
    res_dict = dict()

    # stats
    res_dict.update(get_distribution_features(signal))

    # spectral
    signal -= signal.mean()
    signal /= signal.std()
    res_dict.update(get_fourier_features(signal, n_bins=50))

    # autocorrelation
    res_dict.update(get_autocorr_features(signal, n_lags=200))

    return res_dict

# %%
get_features(signal)
# Out:
# {'mean': np.float64(-2.6841873450192667e-18),
#  'std': np.float64(1.0),
#  'min': np.float64(-5.82980979947499),
#  'max': np.float64(8.535080781784679),
#  'kurtosis': np.float64(15.069250155393355),
#  'skew': np.float64(1.4247103118029765),
#  'q0.25': np.float64(-0.2646969879621181),
#  'q0.50': np.float64(-0.003289456181195984),
#  'q0.75': np.float64(0.24720927319217437),
#  'fourier_0-20_Hz': np.float64(15.773631211188754),
#  'fourier_20-40_Hz': np.float64(18.058406494660073),
#  'fourier_40-60_Hz': np.float64(17.828232535139936),
#  'fourier_60-80_Hz': np.float64(16.99776774880173),
#  'fourier_80-100_Hz': np.float64(15.942609434276333),
#  'fourier_100-120_Hz': np.float64(15.261741988187408),
#  'fourier_120-140_Hz': np.float64(14.365400852373103),
#  'fourier_140-160_Hz': np.float64(13.138115802537095),
#  'fourier_160-180_Hz': np.float64(12.73853392472489),
#  'fourier_180-200_Hz': np.float64(12.145773818342),
#  'fourier_200-220_Hz': np.float64(10.940269137414845),
#  'fourier_220-240_Hz': np.float64(10.282190588673782),
#  'fourier_240-260_Hz': np.float64(9.57824311129101),
#  'fourier_260-280_Hz': np.float64(9.164408218258421),
#  'fourier_280-300_Hz': np.float64(9.342684848263948),
#  'fourier_300-320_Hz': np.float64(9.25935574771269),
#  'fourier_320-340_Hz': np.float64(9.096731570906439),
#  'fourier_340-360_Hz': np.float64(8.599592585569129),
#  'fourier_360-380_Hz': np.float64(8.01658072263535),
#  'fourier_380-400_Hz': np.float64(7.726791379002328),
#  'fourier_400-420_Hz': np.float64(7.627049703895484),
#  'fourier_420-440_Hz': np.float64(7.433492085010664),
#  'fourier_440-460_Hz': np.float64(7.29363829474588),
#  'fourier_460-480_Hz': np.float64(7.091372340318053),
#  'fourier_480-500_Hz': np.float64(7.006495244361374),
#  'fourier_500-520_Hz': np.float64(6.984978092776024),
#  'fourier_520-540_Hz': np.float64(6.911772001561412),
#  'fourier_540-560_Hz': np.float64(6.933984779967091),
#  'autocorrelation_179_lag': np.float64(-0.034522799436507046),
#  'autocorrelation_180_lag': np.float64(-0.034344254013314035),
#  'autocorrelation_181_lag': np.float64(-0.03385743740191677),
#  'autocorrelation_182_lag': np.float64(-0.03299675849277202),
#  'autocorrelation_183_lag': np.float64(-0.03167159681732946),
#  'autocorrelation_184_lag': np.float64(-0.029839087562618372),
#  'autocorrelation_185_lag': np.float64(-0.027466601674094374),
#  'autocorrelation_186_lag': np.float64(-0.024570807302713323),
#  'autocorrelation_187_lag': np.float64(-0.021198069929248987),
#  'autocorrelation_188_lag': np.float64(-0.017427376743271536),
#  'autocorrelation_189_lag': np.float64(-0.013356349144152724),
#  'autocorrelation_190_lag': np.float64(-0.009082299779974034),
#  'autocorrelation_191_lag': np.float64(-0.004715758880810304),
#  'autocorrelation_192_lag': np.float64(-0.00034662190933696844),
#  'autocorrelation_193_lag': np.float64(0.003932939361914022),
#  'autocorrelation_194_lag': np.float64(0.008041099279280445),
#  'autocorrelation_195_lag': np.float64(0.01192045774290469),
#  'autocorrelation_196_lag': np.float64(0.015517731753024929),
#  'autocorrelation_197_lag': np.float64(0.018804141435125887),
#  'autocorrelation_198_lag': np.float64(0.02176526923346353),
#  'autocorrelation_199_lag': np.float64(0.024399369474649883),
#  'autocorrelation_200_lag': np.float64(0.026711067036260555),
#  'lag_max_autocorrelation_Hz': np.float64(30.76923076923077),
#  'max_autocorrelation': np.float64(1.0)}

# %% [markdown]
# Compute all features over the data set.

# %%
all_features = pd.DataFrame(
    [get_features(signal.flatten()) for signal in X_train]
)

# %%
all_features.head()
# Out:
#        mean       std       min       max   kurtosis      skew     q0.25  \
# 0 -0.000044  0.053476 -0.325073  0.291504   4.395775  0.286963 -0.027130
# 1 -0.000026  0.021232 -0.109467  0.139496   4.207598  0.389185 -0.011505
# 2 -0.000069  0.034245 -0.253387  0.291596  22.093219  1.362185 -0.007721
# 3 -0.000026  0.075533 -0.440369  0.644653  15.069250  1.424710 -0.020020
# 4 -0.000021  0.126608 -1.000000  0.999969  20.218365  0.238795 -0.017641
#
#       q0.50     q0.75  fourier_0-20_Hz  ...  autocorrelation_193_lag  \
# 0 -0.000610  0.025116        17.425511  ...                -0.013568
# 1 -0.000244  0.010864        17.947738  ...                 0.147982
# 2 -0.000031  0.007477        15.761979  ...                 0.007707
# 3 -0.000275  0.018646        15.773631  ...                 0.003933
# 4  0.000275  0.016693        15.738893  ...                 0.025114
#
#    autocorrelation_194_lag  autocorrelation_195_lag  autocorrelation_196_lag  \
# 0                -0.010462                -0.007693                -0.005201
# 1                 0.143621                 0.139093                 0.134445
# 2                 0.006197                 0.004491                 0.002655
# 3                 0.008041                 0.011920                 0.015518
# 4                 0.024158                 0.023134                 0.022036
#
#    autocorrelation_197_lag  autocorrelation_198_lag  autocorrelation_199_lag  \
# 0                -0.002915                -0.000772                 0.001283
# 1                 0.129681                 0.124822                 0.119951
# 2                 0.000759                -0.001193                -0.003117
# 3                 0.018804                 0.021765                 0.024399
# 4                 0.020845                 0.019556                 0.018152
#
#    autocorrelation_200_lag  lag_max_autocorrelation_Hz  max_autocorrelation
# 0                 0.003267                   20.000000                  1.0
# 1                 0.115106                   10.869565                  1.0
# 2                -0.005015                   40.816327                  1.0
# 3                 0.026711                   30.769231                  1.0
# 4                 0.016617                   37.037037                  1.0
#
# [5 rows x 262 columns]

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> How many features do we have in the end?</p>
# </div>

# %% [markdown]
# 262

# %% [markdown]
# # Feature selection

# %% [markdown]
# ## Unsupervised selection

# %% [markdown]
# ### Sanity checks

# %% [markdown]
# #### Low variance threshold

# %%
fig, ax = fig_ax(figsize=(20, 5))
all_features.std().sort_values().plot(ax=ax)

# change the height of the horizontal line here
ax.axhline(0.01, ls="--", color="k")

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> Choose a variance threshold (name it <tt>variance_threshold</tt>).</p>
# </div>

# %%
variance_threshold = 0.05

# %% [markdown]
# Be careful when dropping low variance features, they might still be informative. Quickly check that it makes sense to drop them.

# %%
low_variance_features = all_features.std() < variance_threshold
low_variance_features = low_variance_features[
    low_variance_features
].index.to_numpy()
print(f"There are {len(low_variance_features)} features to drop.")
print(low_variance_features)
# Out:
# There are 31 features to drop.
# ['mean' 'q0.25' 'q0.50' 'q0.75' 'autocorrelation_0_lag'
#  'autocorrelation_170_lag' 'autocorrelation_171_lag'
#  'autocorrelation_172_lag' 'autocorrelation_173_lag'
#  'autocorrelation_174_lag' 'autocorrelation_175_lag'
#  'autocorrelation_176_lag' 'autocorrelation_177_lag'
#  'autocorrelation_178_lag' 'autocorrelation_179_lag'
#  'autocorrelation_180_lag' 'autocorrelation_181_lag'
#  'autocorrelation_182_lag' 'autocorrelation_183_lag'
#  'autocorrelation_184_lag' 'autocorrelation_185_lag'
#  'autocorrelation_186_lag' 'autocorrelation_187_lag'
#  'autocorrelation_188_lag' 'autocorrelation_189_lag'
#  'autocorrelation_190_lag' 'autocorrelation_191_lag'
#  'autocorrelation_192_lag' 'autocorrelation_193_lag'
#  'autocorrelation_194_lag' 'max_autocorrelation']

# %% [markdown]
# The following cell drops the low-variance features. Only execute it when you are sure of the features you want to remove.

# %%
all_features.drop(columns=low_variance_features, inplace=True, errors="ignore")
print(f"There are {all_features.shape[1]} features left.")
# Out:
# There are 231 features left.

# %% [markdown]
# #### Check outliers

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> One feature has larger variations than the others: which one is it? (Name it <tt>feature_to_check</tt>.) Show the associated boxplot.</p>
# </div>

# %%
feature_to_check = "lag_max_autocorrelation_Hz"

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> Check the outliers. Is there something we can do to remediate this issue?</p>
# </div>

# %%
all_features[feature_to_chek].hist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 all_features[feature_to_chek].hist()
#
# NameError: name 'feature_to_chek' is not defined

# %% [markdown]
# ### Multicollinearity
#
# Multicollinearity degrades numerical stability and interpretability.
# Compute the correlation.
# Features with a correlation above a threshold are grouped together in a cluster.
# We then choose a single feature from each cluster.

# %%
correlation_threshold = 0.8

# %%
corr = pdist(all_features.to_numpy().T, metric="correlation")  # distance matrix
plt.imshow(squareform(corr))

# %%
fig, ax = fig_ax((20, 10))
corr_linkage = hierarchy.average(corr)
dendro = hierarchy.dendrogram(
    corr_linkage, ax=ax, color_threshold=1 - correlation_threshold
)

# %%
# compute the clusters
cluster_ids = hierarchy.fcluster(
    corr_linkage, 1 - correlation_threshold, criterion="distance"
)

# print the largest clusters
largest_cluster_ind = np.bincount(cluster_ids).argmax()
print(
    f"The largest cluster is {all_features.columns[cluster_ids==largest_cluster_ind].tolist()}."
)

# for each cluster, only keep the first feature
keep_features = list()
for cluster in np.unique(cluster_ids):
    cluster_indexes = np.where(cluster_ids == cluster)[0]
    keep_features.append(all_features.columns[cluster_indexes[0]])

# %%
# Reduce the number of features
all_features = all_features[keep_features]

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> How many features do we have in the end?</p>
# </div>

# %% [markdown]
# ### PCA

# %%
all_features_centered = all_features.to_numpy()

all_features_centered -= all_features_centered.mean(axis=0)
all_features_centered /= all_features_centered.std(axis=0)


pca = PCA(n_components=2).fit(all_features_centered)

# %%
pca = PCA(n_components=2).fit(all_features)

# %%
# select the 5 most important features (with highest norm).
top_features_for_pca = np.linalg.norm(pca.components_, axis=0).argsort()[-5:]

for feature_ind in top_features_for_pca:
    msg = f"{all_features.columns[feature_ind]}: {(pca.components_.T[feature_ind]**2).sum():.3f}"
    print(msg)

# %%
# plot the 2D projection of the top 5 features
fig, ax = fig_ax(figsize=(8, 8))
ax.axis("equal")
for feature_ind in top_features_for_pca:  # normaliser par la variance
    dx, dy = pca.components_.T[feature_ind]
    ax.plot([0, dx], [0, dy], label=all_features.columns[feature_ind])
ax.set_xlabel(f"PC1 ({pca.explained_variance_[0]:.1f}% of variance)")
ax.set_ylabel(f"PC1 ({pca.explained_variance_[1]:.1f}% of variance)")
_ = plt.legend()

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> Normalize all features to unit variance and redo the PCA.</p>
# </div>

# %% [markdown]
# ## Supervised selection

# %% [markdown]
# Three main classes of methods:
#
# - **Filter methods.** We test the adequacy of the feature with the annotations, thanks to several criterion/scores (e.g. correlation).
# - **Wrapper methods.** We test the features on a supervised classification task, by trying several combinations. The best features are kept.
# - **Embedded methods.** Mixed approaches where we jointly infer the relevance of the features and classify the data (decision tree, sparse methods...)

# %% [markdown]
# ### Filter methods
#
# If a feature is highly correlated with a label, it can help achieve good classification performance.
#
# For classification tasks, ANOVA.

# %%
labels = data.y_train
statistics, pvalues = f_oneway(
    all_features[labels == "Abnormal"], all_features[labels == "Normal"]
)

# %%
for ind in statistics.argsort()[::-1]:
    print(f"{all_features.columns[ind]}: {statistics[ind]:.3f}")

# %% [markdown]
# ### Wrapper methods
#
# For a given learning algorithm, wrapper methods repeatedly select a subset of features and evaluate the selected features. Several procedures exist to select a subset but the most common are greedy and iterative; they either remove (backward selection) or add a feature (forward selection) sequentially.

# %%
# At each steps, SequentialFeatureSelector adds the best scoring feature to
# the set of selected features.
# For a given estimator, the score is computed with cross-validation.
knn = KNeighborsClassifier(n_neighbors=5)
sfs = SequentialFeatureSelector(
    knn, n_features_to_select=20, cv=5, scoring=make_scorer(accuracy_score)
)
sfs.fit(all_features, labels)

print("Selected features:")
print(all_features.columns[sfs.get_support()].tolist())

# %% [markdown]
# ### Embedded methods
#
# Such methods use the intrinsic structure of a learning algorithm to embed feature selection into the underlying model.

# %%
rf = RandomForestClassifier().fit(all_features, labels)

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>Print features in descending order of importance, measured by the random forest feature importance (see the <tt>feature_importances_</tt> attribute).</p>
# </div>
